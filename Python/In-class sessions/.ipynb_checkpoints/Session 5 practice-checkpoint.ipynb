# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
survey_df = pd.read_csv('./surveys.csv')
# downloaded from https://ndownloader.figshare.com/files/2292172

# %%
survey_df.describe()
# Out:
#           record_id         month           day          year       plot_id  \
# count  35549.000000  35549.000000  35549.000000  35549.000000  35549.000000
# mean   17775.000000      6.474022     16.105966   1990.475231     11.397001
# std    10262.256696      3.396583      8.256691      7.493355      6.799406
# min        1.000000      1.000000      1.000000   1977.000000      1.000000
# 25%     8888.000000      4.000000      9.000000   1984.000000      5.000000
# 50%    17775.000000      6.000000     16.000000   1990.000000     11.000000
# 75%    26662.000000      9.000000     23.000000   1997.000000     17.000000
# max    35549.000000     12.000000     31.000000   2002.000000     24.000000
#
#        hindfoot_length        weight
# count     31438.000000  32283.000000
# mean         29.287932     42.672428
# std           9.564759     36.631259
# min           2.000000      4.000000
# 25%          21.000000     20.000000
# 50%          32.000000     37.000000
# ...

# %%
survey_df.describe(include = ['O'])
# Out:
#        species_id    sex
# count       34786  33038
# unique         48      2
# top            DM      M
# freq        10596  17348

# %%
survey_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
survey_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
h = survey_df.columns

# %%
h = list(survey_df.columns)

# %%
h
# Out:
# ['record_id',
#  'month',
#  'day',
#  'year',
#  'plot_id',
#  'species_id',
#  'sex',
#  'hindfoot_length',
#  'weight']

# %%
survey_df.shape
# Out:
# (35549, 9)

# %%
survey_df[['plot_id', 'year']]
# Out:
#        plot_id  year
# 0            2  1977
# 1            3  1977
# 2            2  1977
# 3            7  1977
# 4            3  1977
# 5            1  1977
# 6            2  1977
# 7            1  1977
# 8            1  1977
# 9            6  1977
# 10           5  1977
# 11           7  1977
# 12           3  1977
# 13           8  1977
# 14           6  1977
# 15           4  1977
# 16           3  1977
# 17           2  1977
# 18           4  1977
# 19          11  1977
# 20          14  1977
# 21          15  1977
# 22          13  1977
# 23          13  1977
# 24           9  1977
# 25          15  1977
# 26          15  1977
# 27          11  1977
# 28          11  1977
# 29          10  1977
# ...        ...   ...
# 35519        9  2002
# 35520        9  2002
# 35521        9  2002
# 35522        9  2002
# 35523        9  2002
# 35524        9  2002
# 35525        8  2002
# 35526       13  2002
# 35527       13  2002
# 35528       13  2002
# 35529       13  2002
# ...

# %%
survey_df['species_id'].unique()
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
survey_df.species_id.unique(), len(survey_df.species_id.unique())
# Out:
# (array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#         'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#         'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#         'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#         'PB', 'PL', 'PX', 'CT', 'US'], dtype=object), 49)

# %%
survey_df.species_id.nunique()
# Out:
# 48

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35549 entries, 0 to 35548
# Data columns (total 9 columns):
# record_id          35549 non-null int64
# month              35549 non-null int64
# day                35549 non-null int64
# year               35549 non-null int64
# plot_id            35549 non-null int64
# species_id         34786 non-null object
# sex                33038 non-null object
# hindfoot_length    31438 non-null float64
# weight             32283 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.4+ MB

# %%
survey_df_sub = survey_df[['plot_id', 'year']]

# %%
survey_df.groupby('species_id').describe()
# Out:
#            record_id                                                          \
#                count          mean           std      min       25%      50%
# species_id
# AB             303.0  13201.702970   5835.874869   3126.0   7604.00  13829.0
# AH             437.0  21631.716247   7194.381201   1446.0  15507.00  21600.0
# AS               2.0  19760.000000   1170.968830  18932.0  19346.00  19760.0
# BA              46.0  18586.043478    921.349203  16598.0  17972.50  18803.0
# CB              50.0  18300.460000   7271.702586   3189.0  13227.00  19590.5
# CM              13.0   4055.000000   2789.266660   3190.0   3263.00   3291.0
# CQ              16.0   5718.062500   1899.301607   3200.0   3720.75   6199.0
# CS               1.0  15878.000000           NaN  15878.0  15878.00  15878.0
# CT               1.0  28988.000000           NaN  28988.0  28988.00  28988.0
# CU               1.0  21209.000000           NaN  21209.0  21209.00  21209.0
# ...

# %%
survey_df.groupby('species_id').count()
# Out:
#             record_id  month    day   year  plot_id    sex  hindfoot_length  \
# species_id
# AB                303    303    303    303      303      0                0
# AH                437    437    437    437      437      1                2
# AS                  2      2      2      2        2      0                0
# BA                 46     46     46     46       46     45               45
# CB                 50     50     50     50       50      0                0
# CM                 13     13     13     13       13      0                0
# CQ                 16     16     16     16       16      0                0
# CS                  1      1      1      1        1      0                0
# CT                  1      1      1      1        1      0                0
# CU                  1      1      1      1        1      0                0
# CV                  1      1      1      1        1      0                0
# ...

# %%
# %matplotlib inline
survey_df.groupby('sex').count()['record_id'].plot(kind='bar')

# %%
survey_df.groupby(['species_id','sex']).count()['record_id']
# Out:
# species_id  sex
# AH          M         1
# BA          F        31
#             M        14
# DM          F      4554
#             M      5969
# DO          F      1308
#             M      1707
# DS          F      1188
#             M      1270
# NL          F       675
#             M       502
# OL          F       475
#             M       512
# OT          F      1057
#             M      1156
# OX          F         4
#             M         5
# PB          F      1646
#             M      1216
# PE          F       579
#             M       698
# PF          F       757
#             M       816
# PH          F        21
#             M        11
# PI          M         8
# PL          F        16
#             M        19
# PM          F       382
#             M       501
# PP          F      1608
#             M      1468
# PX          F         1
#             M         1
# RF          F        57
#             M        18
# RM          F      1199
# ...

# %%
# %matplotlib inline
survey_df.groupby(['species_id','sex']).count()['record_id'].plot(kind='bar')

# %%
survey_df.groupby(['species_id','sex']).count()['record_id'].unstack().plot(kind='bar',stacked=True)

# %%
survey_df_copy = survey_df.copy() # separated
survey_df_2 = survey_df # joined, will be updated together

# %%
survey_df[['species_id','sex']][2:5]
# Out:
#   species_id sex
# 2         DM   F
# 3         DM   M
# 4         DM   M

# %%
survey_df.iloc[2:5,1:3]
# Out:
#    month  day
# 2      7   16
# 3      7   16
# 4      7   16

# %%
survey_df.loc[2:4,['species_id','sex']]
# Out:
#   species_id sex
# 2         DM   F
# 3         DM   M
# 4         DM   M

# %%
survey_df[survey_df['year']==2000].groupby('sex').count()['record_id']
# Out:
# sex
# F    690
# M    779
# Name: record_id, dtype: int64

# %%
survey_df[(survey_df['year']==2000) & (survey_df['sex']=='M')].groupby('sex').count()['record_id']
# Out:
# sex
# M    779
# Name: record_id, dtype: int64

# %%
survey_df[(survey_df['year']==2000) & (survey_df['sex']=='M')].count()['record_id']
# Out:
# 779

# %%
survey_df[-(survey_df['year']==2000)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
survey_df[survey_df['year'].isin([2000])]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 30158      30159      1    8  2000        1         PP    F             22.0
# 30159      30160      1    8  2000        1         DO    M             35.0
# 30160      30161      1    8  2000        1         PP    F             21.0
# 30161      30162      1    8  2000        1         DM    M             36.0
# 30162      30163      1    8  2000        1         PP    M             20.0
# 30163      30164      1    8  2000        1         PB    M             26.0
# 30164      30165      1    8  2000        1         PP    F             22.0
# 30165      30166      1    8  2000        1         PP    M             23.0
# 30166      30167      1    8  2000        1         DO    M             35.0
# 30167      30168      1    8  2000        1         PB    M             25.0
# 30168      30169      1    8  2000        2         PB    F             25.0
# ...

# %%
survey_df[survey_df['species_id'].isin(['PF','PE','DM'])]['species_id'].unique()
# Out:
# array(['DM', 'PF', 'PE'], dtype=object)

# %%
survey_df[(survey_df['weight']>0)].groupby(['plot_id','sex']).mean()['weight'].unstack().plot(kind='bar',stacked=True)
# groupby already filters our NaN

# %%
survey_df[(survey_df['weight']>0)&((survey_df['sex']=='M')|(survey_df['sex']=='F'))].groupby(['plot_id','sex']).mean()['weight'].unstack().plot(kind='bar',stacked=True)
