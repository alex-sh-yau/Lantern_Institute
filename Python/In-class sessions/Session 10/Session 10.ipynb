# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
from sklearn.model_selection import cross_val_score

# %%
data = pd.read_csv('./data.csv')

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave_points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
data.drop(['id', 'Unnamed:32'], axis=1, inplace=True)

# %%
data['diagnosis'] = data['diagnosis'].map({'M':1,'B':0})

# %%
data.plot()

# %%
data_scaled = pd.DataFrame(preprocessing.scale(data.iloc[:,1:])) # standard-scaled

# %%
data_scaled
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.097064 -2.073335  1.269934  0.984375  1.568466  3.283515  2.652874
# 1    1.829821 -0.353632  1.685955  1.908708 -0.826962 -0.487072 -0.023846
# 2    1.579888  0.456187  1.566503  1.558884  0.942210  1.052926  1.363478
# 3   -0.768909  0.253732 -0.592687 -0.764464  3.283553  3.402909  1.915897
# 4    1.750297 -1.151816  1.776573  1.826229  0.280372  0.539340  1.371011
# 5   -0.476375 -0.835335 -0.387148 -0.505650  2.237421  1.244335  0.866302
# 6    1.170908  0.160649  1.138125  1.095295 -0.123136  0.088295  0.300072
# 7   -0.118517  0.358450 -0.072867 -0.218965  1.604049  1.140102  0.061026
# 8   -0.320167  0.588830 -0.184080 -0.384207  2.201839  1.684010  1.219096
# 9   -0.473535  1.105439 -0.329482 -0.509063  1.582699  2.563358  1.738872
# 10   0.537556  0.919273  0.442011  0.406453 -1.017686 -0.713542 -0.700684
# 11   0.469393 -0.325708  0.479082  0.358672  0.052642  0.471115  0.134849
# ...

# %%
data_scaled.plot()

# %%
data.diagnosis.value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), vmax=1, square=True)

# %%
data_scaled.columns = list(data.columns[1:])

# %%
data_scaled
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# 5      -0.476375     -0.835335       -0.387148  -0.505650         2.237421
# 6       1.170908      0.160649        1.138125   1.095295        -0.123136
# 7      -0.118517      0.358450       -0.072867  -0.218965         1.604049
# 8      -0.320167      0.588830       -0.184080  -0.384207         2.201839
# 9      -0.473535      1.105439       -0.329482  -0.509063         1.582699
# 10      0.537556      0.919273        0.442011   0.406453        -1.017686
# ...

# %%
mean_cols = [c for c in data_scaled.columns if 'mean' in c]

# %%
data_scaled_means = data_scaled[mean_cols]

# %%
data_scaled_means
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# 5      -0.476375     -0.835335       -0.387148  -0.505650         2.237421
# 6       1.170908      0.160649        1.138125   1.095295        -0.123136
# 7      -0.118517      0.358450       -0.072867  -0.218965         1.604049
# 8      -0.320167      0.588830       -0.184080  -0.384207         2.201839
# 9      -0.473535      1.105439       -0.329482  -0.509063         1.582699
# 10      0.537556      0.919273        0.442011   0.406453        -1.017686
# ...

# %%
X = data_scaled_means
y = data.diagnosis.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(y_train)
# Out:
# 455

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10, p=2, metric='minkowski')
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#            weights='uniform')

# %%
from sklearn.metrics import accuracy_score
y_pred = knn.predict(X_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred))
print('Misclassified samples: %d' % (y_test != y_pred).sum())
# Out:
# Accuracy: 0.9123
# Misclassified samples: 10

# %%
y_pred = knn.predict(X_train)
print(accuracy_score(y_train, y_pred))
# Out:
# 0.9582417582417583

# %%
confusion_matrix(y_train, y_pred)
# Out:
# array([[283,   5],
#        [ 14, 153]], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dcstc = DecisionTreeClassifier()
dcstc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred = dcstc.predict(X_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred))
print('Misclassified samples: %d' % (y_test != y_pred).sum())
# Out:
# Accuracy: 0.8772
# Misclassified samples: 14

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[51, 10],
#        [ 4, 49]], dtype=int64)

# %%
y_pred = dcstc.predict(X_train)
print(accuracy_score(y_train, y_pred))
# Out:
# 1.0

# %%
confusion_matrix(y_train, y_pred)
# Out:
# array([[296,   0],
#        [  0, 159]], dtype=int64)

# %%
cross_val_score(dcstc, X_train, y_train, cv=10).mean()
# Out:
# 0.9188866930171278

# %%
cross_val_score(dcstc, X_test, y_test, cv=10).mean()
# Out:
# 0.8966200466200467

# %%
dcstc.feature_importances_
# Out:
# array([0.        , 0.10882135, 0.03443507, 0.04324456, 0.01326096,
#        0.0264135 , 0.00953247, 0.75865671, 0.        , 0.00563538])

# %%
data_scaled_means.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean'],
#       dtype='object')

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus


feature_cols=[col for col in data_scaled.columns if 'mean' in col]

dot_data = StringIO()
export_graphviz(dcstc, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('dt.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-206-d4c1c9ba6377> in <module>
#      12                 special_characters=True, feature_names = feature_cols,class_names=['0','1'])
#      13 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ---> 14 graph.write_png('dt.png')
#      15 Image(graph.create_png())
#
# ~\Anaconda3\lib\site-packages\pydotplus\graphviz.py in <lambda>(path, f, prog)
#    1808                 lambda path,
#    1809                 f=frmt,
# -> 1810                 prog=self.prog: self.write(path, format=f, prog=prog)
#    1811             )
#    1812
#
# ~\Anaconda3\lib\site-packages\pydotplus\graphviz.py in write(self, path, prog, format)
#    1916
#    1917             else:
# -> 1918                 fobj.write(self.create(prog, format))
#    1919         finally:
#    1920             if close:
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# C:\Users\alexy\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = rfc.predict(X_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred))
print('Misclassified samples: %d' % (y_test != y_pred).sum())
# Out:
# Accuracy: 0.9298
# Misclassified samples: 8

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[56,  5],
#        [ 3, 50]], dtype=int64)

# %%
y_pred = rfc.predict(X_train)
print(accuracy_score(y_train, y_pred))
# Out:
# 0.9978021978021978

# %%
confusion_matrix(y_train, y_pred)
# Out:
# array([[296,   0],
#        [  1, 158]], dtype=int64)

# %%
cross_val_score(rfc, X_train, y_train, cv=10).mean()
# Out:
# 0.9231335090030741

# %%
cross_val_score(rfc, X_test, y_test, cv=10).mean()
# Out:
# 0.9063519813519813

# %%
rfc.feature_importances_
# Out:
# array([0.14397201, 0.06097472, 0.03965309, 0.15705084, 0.0202833 ,
#        0.0364967 , 0.09947197, 0.39772356, 0.01818089, 0.02619291])

# %%
for i in range(1,10):
    dcstc = DecisionTreeClassifier(max_depth=i)
    score=cross_val_score(dcstc, X_train, y_train, cv=10).mean()
    print(i, score)
# Out:
# 1 0.9167632850241546
# 2 0.9208651734738693
# 3 0.9343478260869565
# 4 0.929852876592007
# 5 0.9253601229688186
# 6 0.9188866930171278
# 7 0.9189833113746158
# 8 0.9123166447079492
# 9 0.9144883618796662

# %%
# Out:
# array([[51, 10],
#        [ 4, 49]], dtype=int64)
