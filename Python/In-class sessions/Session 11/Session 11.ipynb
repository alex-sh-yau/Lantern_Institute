# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from sklearn import model_selection, metrics, linear_model, datasets, feature_selection, preprocessing

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
n = np.random.rand(100,5)

# %%
X = n[:,0:4]
y = n[:,4]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
from sklearn.metrics import mean_squared_error
y_pred = reg.predict(X_test)
print('MSE: %.4f' % mean_squared_error(y_test, y_pred))
# Out:
# MSE: 0.0597

# %%
house_df = pd.read_csv('./kc_house_data.csv')

# %%
house_df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
features= ['bedrooms','sqft_living','sqft_lot','floors','waterfront','view','condition','grade',
           'sqft_basement','yr_built','yr_renovated','sqft_living15','sqft_lot15']

# %%
from sklearn import feature_selection

# %%
feature_importances = feature_selection.mutual_info_regression(house_df[features], house_df['price'])

# %%
feature_importances
# Out:
# array([0.07476651, 0.3536482 , 0.06209475, 0.07426554, 0.00885843,
#        0.05630335, 0.01866978, 0.34380547, 0.07576762, 0.07409557,
#        0.01296198, 0.26963768, 0.08186547])

# %%
for z in zip(features,feature_importances):
    print(z)
# Out:
# ('bedrooms', 0.07476651383703237)
# ('sqft_living', 0.3536481960970992)
# ('sqft_lot', 0.062094747793368654)
# ('floors', 0.07426553552876358)
# ('waterfront', 0.008858429862018458)
# ('view', 0.05630335426292943)
# ('condition', 0.01866978365613381)
# ('grade', 0.3438054650346509)
# ('sqft_basement', 0.07576762320726882)
# ('yr_built', 0.07409557147706192)
# ('yr_renovated', 0.012961981508551101)
# ('sqft_living15', 0.2696376772503486)
# ('sqft_lot15', 0.08186546951289575)

# %%
feat_df = pd.DataFrame(list(zip(features,feature_importances)), columns=['features', 'importance'])

# %%
feat_df
# Out:
#          features  importance
# 0        bedrooms    0.074767
# 1     sqft_living    0.353648
# 2        sqft_lot    0.062095
# 3          floors    0.074266
# 4      waterfront    0.008858
# 5            view    0.056303
# 6       condition    0.018670
# 7           grade    0.343805
# 8   sqft_basement    0.075768
# 9        yr_built    0.074096
# 10   yr_renovated    0.012962
# 11  sqft_living15    0.269638
# 12     sqft_lot15    0.081865

# %%
features= ['bedrooms','sqft_living','sqft_lot','floors','waterfront','view','condition','grade',
           'Sqft_basement','yr_built','yr_renovated','sqft_living15','sqft_lot15']


new_ft=feat_df.sort_values('importance').iloc[-4:]['features']
X=data[new_ft]
y=data['price']
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X)
X_train_std = sc.transform(X)
reg.fit(X,y)
y_pred = reg.predict(X)
residual= y_pred-y
plt.plot(residual)




best_feats = list(feat_df.sort_values('importances', ascending = False)['features'][0:5])

df['year'] = [float(d[0:4]) for d in df['date'].values]


best_cols = ['sqft_living', 'grade', 'sqft_living15', 'bedrooms']
df_best = df[best_cols]
df_scaled = pd.DataFrame(preprocessing.scale(df_best))

X_train, X_test, y_train, y_test = train_test_split(df_scaled, df.price, test_size=0.2)

lreg = LinearRegression()
lreg.fit(X_train, y_train)
y_pred = lreg.predict(X_test)
y_pred

# %% [markdown]
# # ahh shit too lazy

# %% [markdown]
# ______

# %%
from sklearn.datasets import make_blobs, make_moons


X,y = make_blobs(n_features=2, n_samples=1000, cluster_std=.5)

# %%
plt.scatter(X[:,0],X[:,1],s=10, c=y)

# %%
from sklearn.cluster import KMeans, MeanShift

# %%
kmc=KMeans(n_clusters=5)

# %%
kmc.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
plt.scatter(X[:,0],X[:,1],s=10, c=kmc.predict(X))

# %%
from sklearn.metrics.cluster import completeness_score
